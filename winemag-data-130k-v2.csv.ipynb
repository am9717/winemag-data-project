# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("winemag-data-130k-v2.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %%
df.shape
# Out:
# (129971, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            92506 non-null   object
#  4   points                 129971 non-null  int64
#  5   price                  120975 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               108724 non-null  object
#  8   region_2               50511 non-null   object
#  9   taster_name            103727 non-null  object
#  10  taster_twitter_handle  98758 non-null   object
#  11  title                  129971 non-null  object
#  12  variety                129970 non-null  object
#  13  winery                 129971 non-null  object
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
import pandas as pd

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
# second way to del the column 
del df['Unnamed: 0']
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Unnamed: 0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#Expt to text file 
df.to_csv('df.txt',shape)

# %%
df.isnull().sum()

# %%
df.fillna(9999,inplace=True)

# %%
df.isnull().sum()

# %%
df

# %%
import seaborn as sns

# %%
#1.Which countries produce the most wines in the dataset?
plt.figure(figsize=(9,8))
sns.barplot(x=country_counts.values,y=country_counts.index,data=df)

plt.title("winery by country")
plt.show()

# %%
# 2.What is the average price of wine across different countries?
plt.figure(figsize=(9,8))
average_price_by_country = df.groupby('country')['price'].mean().sort_values(ascending=False).head(10)

sns.barplot(x=average_price_by_country.values, y=average_price_by_country.index, palette='viridis')

plt.title("This is PRice by country")
plt.show()

# %%
# 3.Which country produces the highest-rated wines on average?

plt.figure(figsize=(9,8))
average_rating_by_country= df.groupby('country')['points'].mean().sort_values(ascending=False).head(10)
sns.barplot(x = average_rating_by_country.values,y= average_rating_by_country.index,data=df)
plt.title('Average Rating of Wines Across Different Countries')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#4.What are the most common wine varieties in the dataset?
plt.figure(figsize=(9,8))
top_varieties = df['variety'].value_counts().head(10)
sns.barplot(x=top_varieties.values,y=top_varieties.index,palette='viridis', data=df)
plt.title("Top 10 Varities ")
plt.show()

# %%
#5.Do wines from specific regions tend to have higher ratings?

# %%
#5.Do wines from specific regions tend to have higher ratings?
plt.figure(figsize=(9,8))
average_rating_by_region = df.groupby('region_1')['points'].mean().sort_values(ascending=False).head(10)
sns.barplot(x=average_rating_by_region.values, y=average_rating_by_region.index, palette='viridis')
plt.title("specific_regions")
plt.show()

# %%
#6.Is there a relationship between the price and rating of wines?

plt.figure(figsize=(9,8))
sns.scatterplot(x='price',y = 'points',data=df)
plt.title('Relationship Between Wine Price and Rating')
plt.show()

# %%
#7.Which wineries produce the most expensive wines on average?

plt.figure(figsize=(9,8))
average_price_by_winery = df.groupby('winery')['price'].mean().sort_values(ascending=False).head(10)
sns.barplot(x=average_price_by_winery.values,y=average_price_by_winery.index,data=df)
plt.title("THis is Avrage_price_by_wnery")
plt.show()

# %%
#8.What are the top-rated wines by designation?

average_points_by_designation = df.groupby('designation')['points'].mean().sort_values(ascending=False).head(10)
plt.figure(figsize=(9,8))
sns.barplot(x=average_points_by_designation.values,y=average_points_by_designation.index)
plt.title('Top 10 rated by designation')
plt.show()

# %%
#9.Do wines with a designation tend to have higher ratings?

# %%
plt.figure(figsize=(9,8))

average_points_with_designation = df[df['designation'].notnull()]['points'].mean()

average_points_without_designation = df[df['designation'].isnull()]['points'].mean()


sns.barplot(x= ['with_designation','without_designation'],y=[average_points_with_designation,average_points_without_designation])


plt.title("Average Ratings with and without Designation")
plt.show()

# %%
#10.Are there any trends in wine ratings over the years?

# %%
# create a new column is Year from title
df['Year'] = df['title'].str.extract(r'(\d{4})')
df['Year'] = pd.to_numeric(df['Year'],errors='coerce')
print(df.head())
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
#10.Are there any trends in wine ratings over the years?

plt.figure(figsize=(9,8))
sns.lineplot(x='Year',y='points',data=df)
plt.title("Wine Ratings Over the Years")
plt.show()

# %%
#11.Which taster has reviewed the most wines in the dataset?

# %%
#11.Which taster has reviewed the most wines in the dataset?

plt.figure(figsize=(9,8))
count_by_taster = df['taster_name'].value_counts().head(10)
sns.barplot(x=count_by_taster.values,y=count_by_taster.index)
plt.title("Taster by most wines")
plt.show()

# %%
#12.Is there a correlation between the taster's rating and the wine's price?

# %%
plt.figure(figsize=(8,7))
sns.scatterplot(x= 'price',y='points',data=df)
plt.title("this is no language")
plt.show()

# %%
#13.What are the most common grape varieties used in winemaking?

common_grape_varieties = df['variety'].value_counts().head(10)

# Print the top 10 most common grape varieties
print("Top 10 Most Common Grape Varieties:")
print(common_grape_varieties)
# Out:
# Top 10 Most Common Grape Varieties:
# Pinot Noir                  13272
# Chardonnay                  11753
# Cabernet Sauvignon           9472
# Red Blend                    8946
# Bordeaux-style Red Blend     6915
# Riesling                     5189
# Sauvignon Blanc              4967
# Syrah                        4142
# Rosé                         3564
# Merlot                       3102
# Name: variety, dtype: int64

# %%
#14.Do certain grape varieties tend to receive higher ratings?

# %%
#14.Do certain grape varieties tend to receive higher ratings?
plt.figure(figsize=(9,8))
higher_varietis_by_rating = df.groupby('variety')['points'].mean().sort_values(ascending=False).head(10)

sns.barplot(x = higher_varietis_by_rating.values,y = higher_varietis_by_rating.index,data=df)
plt.title("higher ratings by varieties")
plt.show()

# %%
#15.Which provinces produce the most expensive wines on average?

plt.figure(figsize=(9,8))
average_price_by_province = df.groupby('province')['price'].mean().sort_values(ascending=False).head(10)
sns.barplot(x = average_price_by_province.values,y=average_price_by_province.index)
plt.title("Top 10 Provinces by Average Wine Price")
plt.show()

# %%
# 16.Are there any differences in wine prices between 
# regions within the same province?

# %%
plt.figure(figsize=(9,8))
average_price_by_region = df.groupby(['province', 'region_1'])['price'].mean().reset_index().head(10)
sns.boxplot(x='price', y='province', data=average_price_by_region, palette='viridis')
plt.title("Differences in Wine Prices Between Regions Within the Same Province")
plt.show()

# %%
#18.Is there a relationship between the length of a wine description and 
# its rating?

# %%
plt.figure(figsize=(9,8))
df['description_length'] = df['description'].apply(len)

sns.scatterplot(x='description_length',y= 'points',data=df)
plt.title("Relationship Between Description Length and Wine Rating")
plt.show()

# %%
# 19.Do wines with longer titles tend to have higher prices?

# %%
plt.figure(figsize=(9,8))
sns.barplot(x='title',y='price',data=df)
plt.title('Longer title with higher prices')
plt.show()

# %%
df
